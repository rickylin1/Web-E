# %%
import pandas as pd

df_appliances = pd.read_csv("costco_data.csv")
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Allow unlimited width of display

# Display your DataFrame
df_appliances
# Out:
#                                                  name          brand price  \
# 0   Whirlpool 1.6 cu. ft. Washer and 3.4 cu. ft. D...      Whirlpool    --
# 1   GE Unitized Spacemaker 3.8 cu. ft. Washer and ...  GE Appliances    --
# 2   Whirlpool 7.0 cu. ft. Front Load ELECTRIC Drye...      Whirlpool    --
# 3   Samsung 7.4 cu. ft. Smart GAS Dryer with Steam...        Samsung    --
# 4   Samsung 4.1 cu. ft. Capacity Top Load Washer w...        Samsung    --
# 5   Frigidaire ELECTRIC Washer/Dryer Laundry Cente...     Frigidaire    --
# 6   GE 4.5 cu. ft. Washer with Stainless Steel Bas...  GE Appliances    --
# 7   LG 4.3 cu. ft. Top Load Washer with 4-Way Agit...             LG    --
# 8   GE Unitized Spacemaker 3.8 cu. ft. Washer and ...  GE Appliances    --
# 9   GE 4.6 cu. ft. Capacity Washer with Stainless ...  GE Appliances    --
# 10  Maytag 4.5 cu. ft. Top Load Washer with Deep F...         Maytag    --
# ...

# %%
df_beauty = pd.read_csv("costco_data.csv")
df_beauty
# Out:
#                                                  name             brand  \
# 0   Perricone MD Hypoallergenic Clean Correction F...      Perricone MD
# 1   Perricone MD Hypoallergenic Clean Correction B...      Perricone MD
# 2   BIOHEAL BOH Vitamin Toning All Melting Cleansi...       BIOHEAL BOH
# 3                  NuReveal Lactic Rescue Toner, 4 oz          NuReveal
# 4   Beauty of Joseon Glow Serum Propolis + Niacina...  Beauty of Joseon
# 5     True Moringa Shea & Moringa Balm 1.4 oz, 2-pack      True Moringa
# 6              La Mer The Treatment Lotion, 5.0 fl oz            LA MER
# 7   Volition Getaway Glow Gradual Self Tanning Fac...          Volition
# 8   Shiseido Future Solution Lx Enmei Eye Cream 0....          SHISEIDO
# 9   NIGHT Hyaluronic Acid Anti-Aging Silk Sheet Ma...             NIGHT
# 10  Further Food Grass-Fed Collagen Peptides Powde...      Further Food
# 11         La Prairie Skin Caviar Liquid Lift, 1.7 oz        la prairie
# ...
